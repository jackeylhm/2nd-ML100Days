# %%
import os
import numpy as np
import pandas as pd

# Set directory of data 
dir_data = 'D:\Document\AI\Marathon100D\Assignment\Day_005\data'

# %%
# Set the full file path
f_app_train = os.path.join(dir_data, 'application_train.csv')

# Read the csv data file into data frame
df_app_train = pd.read_csv(f_app_train)

# %%
# import visual data ploter
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 練習時間

# %% [markdown]
# 觀察有興趣的欄位的資料分佈，並嘗試找出有趣的訊息
# #### Eg
# - 計算任意欄位的平均數及標準差
# - 畫出任意欄位的[直方圖](https://zh.wikipedia.org/zh-tw/%E7%9B%B4%E6%96%B9%E5%9B%BE)
#
# ### Hints:
# - [Descriptive Statistics For pandas Dataframe](https://chrisalbon.com/python/data_wrangling/pandas_dataframe_descriptive_stats/)
# - [pandas 中的繪圖函數](https://amaozhao.gitbooks.io/pandas-notebook/content/pandas%E4%B8%AD%E7%9A%84%E7%BB%98%E5%9B%BE%E5%87%BD%E6%95%B0.html)

# %%
# Calculate the mean of column AMT_GOODS_PRICE
meanAIT = df_app_train["AMT_GOODS_PRICE"].mean(axis = 0, skipna = True) 
print('Mean of column AMT_GOODS_PRICE: %s' % (meanAIT))

# Calculate the standard deviation of column AMT_GOODS_PRICE
stdAIT = df_app_train["AMT_GOODS_PRICE"].std(axis = 0, skipna = True) 
print('Standard deviation of column AMT_GOODS_PRICE: %s' % (stdAIT))
# Out:
# Mean of column AMT_GOODS_PRICE: 538396.2074288895
# Standard deviation of column AMT_GOODS_PRICE: 369446.4605400129

# %%
# Create a 20 bins histogram for AMT_GOODS_PRICE
# df_app_train["AMT_GOODS_PRICE"].plot.hist()
df_app_train.hist(column='AMT_GOODS_PRICE', bins=20, grid=False, figsize=(20,8), color='#86bf91', zorder=2, rwidth=0.9)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015D816C4860>]],
#       dtype=object)
